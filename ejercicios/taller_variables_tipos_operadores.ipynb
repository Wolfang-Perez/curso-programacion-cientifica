# %% [markdown]
# <a href="https://colab.research.google.com/github/Wolfang-Perez/curso-programacion-cientifica/blob/main/ejercicios/taller_variables_tipos_operadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller de variables, tipos de datos y operadores.

# %% [markdown]
#  ## Ejercicio 1 — Inventario de la tienda

# %% [markdown]
# Una tienda pequeña tiene el siguiente inventario:
#
# Productos y precios (en pesos colombianos):
# - Cuaderno: 3500
# - Lápiz: 800
# - Café: 6200.50
# Cantidad a comprar: 3 cuadernos, 5 lápices
# La tienda tiene actualmente descuentos activos: no

# %% [markdown]
# ### TODO: declare nombre_producto (str) con el nombre de un producto de su elección

# %%
nombre_producto = "Lapiz"

# %% [markdown]
# ### TODO: declare precio_cuaderno (int) y precio_lapiz (int)

# %%
precio_cuaderno = 3500
precio_lapiz = 800

# %% [markdown]
# ### TODO: declare precio_cafe (float)

# %%
precio_cafe = 6200.50

# %% [markdown]
# ### TODO: declare hay_descuento (bool) indicando si la tienda tiene descuentos activos

# %%
hay_descuento = False

# %% [markdown]
# ### TODO: declare cantidad_cuadernos (int) y cantidad_lapices (int)

# %%
cantidad_cuadernos = 3
cantidad_lapices = 5

# %% [markdown]
# ### TODO: verifique con type() el tipo de cada una de las variables anteriores

# %%
print(type(nombre_producto))
print(type(precio_cuaderno))
print(type(precio_lapiz))
print(type(precio_cafe))
print(type(hay_descuento))
print(type(cantidad_cuadernos))
print(type(cantidad_lapices))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# ## Ejercicio 2 — Total de la compra y descuento

# %% [markdown]
# ### TODO: calcule total_cuadernos (precio_cuaderno * cantidad_cuadernos) y muéstrelo con print()

# %%
total_cuadernos = precio_cuaderno * cantidad_cuadernos
print(f"Total cuadernos: {total_cuadernos}")
# Out:
# Total cuadernos: 10500

# %% [markdown]
# ### TODO: calcule total_lapices (precio_lapiz * cantidad_lapices) y muéstrelo con print()

# %%
total_lapices = precio_lapiz * cantidad_lapices
print(f"Total lapices: {total_lapices}")
# Out:
# Total lapices: 4000

# %% [markdown]
# ### TODO: calcule total_general sumando total_cuadernos, total_lapices y precio_cafe

# %%
total_general = total_cuadernos + total_lapices + precio_cafe

# %% [markdown]
# ### TODO: calcule un descuento del 10% sobre total_general

# %%
descuento = total_general * 0.9

# %% [markdown]
# ### TODO: calcule total_con_descuento restando el descuento a total_general

# %%
total_con_descuento = total_general - descuento

# %% [markdown]
# ## Ejercicio 3 — Reparto en paquetes

# %% [markdown]
# ### TODO: calcule cuántos paquetes completos de 4 cuadernos se pueden armar con cantidad_cuadernos (división entera)

# %%
cuadernos_de_a_cuatro = cantidad_cuadernos // 4

# %% [markdown]
# ### TODO: calcule cuántos cuadernos sueltos quedan (módulo)

# %%
cuadernos_sin_paquete = cantidad_cuadernos % 4

# %% [markdown]
# ### TODO: calcule el precio del café elevado al cuadrado

# %%
cafe_square = precio_cafe ** 2

# %% [markdown]
# ### TODO: muestre los tres resultados con print()

# %%
print(f"""
  Cuadernos de a cuatro: {cuadernos_de_a_cuatro}
  Cuadernos restantes: {cuadernos_sin_paquete}
  El precio del café al cuadraro: {cafe_square}
""")
# Out:
#   Cuadernos de a cuatro: 0
#   Cuadernos restantes: 3
#   El precio del café al cuadraro: 38446200.25

# %% [markdown]
# ## Ejercicio 4 — Comparar precios de café

# %% [markdown]
# ### TODO: declare precio_marca_a y precio_marca_b

# %%
precio_marca_a = 15900
precio_marca_b = 14500

# %% [markdown]
# ### TODO: evalúe y muestre con print() cuál marca es más barata

# %%
marca_barata =  precio_marca_a if precio_marca_b > precio_marca_a else precio_marca_b
print(f"Marca mas barata: {"Marca A" if precio_marca_b > precio_marca_a else "Marca B"}")
# Out:
# Marca mas barata: Marca B

# %% [markdown]
# ### TODO: evalúe y muestre con print() si ambas marcas cuestan lo mismo

# %%
marcas_igual_costo = precio_marca_a == precio_marca_b
print(f"Las marcas cuestan lo mismo: {"Sí" if marcas_igual_costo else "No"}")
# Out:
# Las marcas cuestan lo mismo: No

# %% [markdown]
# ## Ejercicio 5 — Promedio y comparación de temperaturas

# %% [markdown]
# Temperaturas registradas (en grados Celsius):
# - Lunes: 18.5
# - Martes: 21.0
# - Miércoles: 19.8
#
# Temperatura promedio de referencia de la semana: 20.0

# %% [markdown]
# ### TODO: declare temp_lunes, temp_martes, temp_miercoles y temp_promedio_semana (float)

# %%
temp_lunes = 18.5
temp_martes = 21.0
temp_miercoles = 19.8
temp_promedio_semana = 20.0

# %% [markdown]
# ### TODO: calcule el promedio de los tres días y muéstrelo con print()

# %%
promedio = (temp_lunes + temp_martes + temp_miercoles) / 3
print(f"Promedio de temperatura: {promedio}")
# Out:
# Promedio de temperatura: 19.766666666666666

# %% [markdown]
# ### TODO: calcule la diferencia entre la temperatura del martes y la del lunes

# %%
diferencia_martes_lunes = temp_martes - temp_lunes

# %% [markdown]
# ### TODO: evalúe y muestre con print() si el martes fue más caluroso que el promedio de referencia

# %%
martes_mas_temp_promedio = "Sí" if temp_martes > promedio else "No"
print(f"{martes_mas_temp_promedio}, el martes {martes_mas_temp_promedio.lower()} fue mas caluroso que el promedio de días.")
# Out:
# Sí, el martes sí fue mas caluroso que el promedio de días.

# %% [markdown]
# ### TODO: evalúe y muestre con print() si el miércoles fue igual al promedio de referencia

# %%
miercoles_igual_promedio_referencia = "Sí" if temp_miercoles == temp_promedio_semana else "No"
print(f"{miercoles_igual_promedio_referencia}, el míercoles {miercoles_igual_promedio_referencia.lower()} es igual al promedio de referencia.")
# Out:
# No, el míercoles no es igual al promedio de referencia.

# %% [markdown]
# ### TODO: evalúe y muestre con print() si el lunes fue el día más frío de los tres (comparándolo con los otros dos)

# %%
lunes_el_mas_frio = "No" if temp_lunes > temp_martes else ("No" if temp_lunes > temp_miercoles else "Sí")
print(f"{lunes_el_mas_frio}, el lunes {lunes_el_mas_frio.lower()} es el día más frío de la semana.")
# Out:
# Sí, el lunes sí es el día más frío de la semana.

# %% [markdown]
# ## Ejercicio 6 — Temperatura templada y día caluroso

# %% [markdown]
# ### TODO: evalúe y muestre con print() si el lunes tuvo una temperatura "templada", entendida como un valor entre 15 y 25 grados (combine dos comparaciones con "and")

# %%
lunes_templado = "Sí" if temp_lunes > 15 and temp_lunes < 25 else "No"
print(f"{lunes_templado}, el lunes {lunes_templado.lower()} es un día templado.")
# Out:
# Sí, el lunes sí es un día templado.

# %% [markdown]
# ### TODO: evalúe y muestre con print() si al menos uno de los tres días superó los 20 grados (combine tres comparaciones con "or")

# %%
supero_veinte_grados = "Sí" if temp_lunes > 20 or temp_martes > 20 or temp_miercoles > 20 else "No"
print(f"{supero_veinte_grados} se superó los 20 grados.")
# Out:
# Sí se superó los 20 grados.

# %% [markdown]
# ## Ejercicio 7 — Factura de servicios y consumo normal

# %% [markdown]
# ### TODO: declare consumo_kwh (int) y tarifa_kwh (float)

# %%
consumo_kwh = 142
tarifa_kwh = 623.5

# %% [markdown]
# ### TODO: calcule el total a pagar (consumo_kwh * tarifa_kwh) y muéstrelo con print()

# %%
total_a_pagar = consumo_kwh * tarifa_kwh
print(f"Tarifa total: {total_a_pagar}")
# Out:
# Tarifa total: 88537.0

# %% [markdown]
# ### TODO: evalúe si consumo_kwh es mayor o igual a 100.

# %%
consumo_mayor_cien = "Sí" if consumo_kwh >= 100 else "No"
print(f"El consumo {consumo_mayor_cien.lower()} es mayor a 100")
# Out:
# El consumo sí es mayor a 100

# %% [markdown]
# ### TODO: evalúe si consumo_kwh es menor o igual a 200

# %%
consumo_menor_200 = "Sí" if consumo_kwh <= 200 else "No"
print(f"El consumo {consumo_menor_200.lower()} es menor a 200")
# Out:
# El consumo sí es menor a 200

# %% [markdown]
# ### TODO: combine ambas evaluaciones con "and" y muestre con print() si el consumo es normal

# %%
consumo_entre_100_200 = "Sí" if consumo_kwh <= 200 and consumo_kwh >= 100 else "No"
print(f"El consumo {consumo_entre_100_200.lower()} es menor a 200 y mayor a 100.")
# Out:
# El consumo sí es menor a 200 y mayor a 100.

# %% [markdown]
# ## Ejercicio 8 — Promedio de calificaciones y aprobación

# %% [markdown]
# ### TODO: declare las tres notas parciales

# %%
nota_parcial_1 = 4.2
nota_parcial_2 = 3.5
nota_parcial_3 = 4.8

# %% [markdown]
# ### TODO: calcule el promedio y muéstrelo con print()

# %%
promedio_notas = (4.2 + 3.5 + 4.8) / 3
print(f"Promedio de las notas: {promedio_notas}")
# Out:
# Promedio de las notas: 4.166666666666667

# %% [markdown]
# ### TODO: evalúe y muestre con print() si el promedio es mayor o igual a 3.0 (aprobación)

# %%
aprobo = "Sí" if promedio_notas >= 3.0 else "No"
print(f"Aprobó: {aprobo}")
# Out:
# Aprobó: Sí

# %% [markdown]
# ## Ejercicio 9 — Aprobación y asistencia

# %% [markdown]
# ### TODO: declare asistencia_porcentaje

# %%
asistencia_porcentaje =  85

# %% [markdown]
# ### TODO:evalúe si el promedio del Ejercicio 8 corresponde a una reprobación (menor a 3.0)

# %%
reprobacion = promedio_notas < 3.0

# %% [markdown]
# ### TODO: muestre con print(), usando "not", si el estudiante NO reprobó

# %%
print("El estudiante no reprobó." if not reprobacion else "El estudianete reprobó." )
# Out:
# El estudiante no reprobó.

# %% [markdown]
# ## Ejercicio 10 — Intercambiar dos precios

# %% [markdown]
# ### TODO: muestre con print() los valores antes de intercambiar

# %%
precio_tornillo = 250
precio_tuerca = 180

print(f"""
  Precio tornillo: {precio_tornillo}
  Precio tuerca: {precio_tuerca}
""")
# Out:
#   Precio tornillo: 250
#   Precio tuerca: 180

# %% [markdown]
# ### TODO: intercambie los valores de precio_tornillo y precio_tuerca usando una variable temporal (por ejemplo, "temporal")

# %%
temporal = precio_tuerca
precio_tuerca = precio_tornillo
precio_tornillo = temporal

# %% [markdown]
# ### TODO: muestre con print() los valores después de intercambiar, para confirmar el intercambio

# %%
print(f"""
  Precio tornillo: {precio_tornillo}
  Precio tuerca: {precio_tuerca}
""")
# Out:
#   Precio tornillo: 180
#   Precio tuerca: 250

# %% [markdown]
# # Bonus:

# %% [markdown]
# - Investigar qué hace el operador % con números negativos y documentar el resultado en una celda de texto.

# %% [markdown]
# En Python, el operador % calcula el módulo y su signo siempre coincide con el del divisor (el segundo número). Sigue la fórmula matemática a % b = a - (b * floor(a / b)), donde el resultado del residuo toma el signo del divisor y no el del dividendo

# %% [markdown]
# - Calcular el resultado de una expresión con varios operadores combinados y explicar en una celda de texto el orden exacto en que Python la evaluó.

# %%
resultado = True or not False and False
print(resultado)
# Out:
# True

# %% [markdown]
# ### Orden de evaluación (Precedencia)
#
# Python evalúa los operadores lógicos de mayor a menor prioridad según las reglas de **precedencia**:
#
# 1. **not** (Máxima prioridad): Se evalúa primero. Convierte not False en True.
#
# > Expresión restante:
# > True or True and False
#
# 2. **and** (Prioridad media): Se evalúa segundo. Calcula True and False, lo cual resulta en False.
#
# >Expresión restante:
# >True or False
#
# 3. **or** (Menor prioridad): Se evalúa al final. Calcula True or False, lo cual resulta en el valor exacto:
#
# >True.

# %% [markdown]
# ## **Tiempo de un viaje:** dado un viaje de 350.0 km recorrido a una velocidad promedio de 80 km/h, calcule el tiempo estimado en horas con el operador de división (/) y verifique con type() el tipo del resultado.
#
# > Agregar bloque entrecomillado

# %%
recorrido_km = 350.0
velocidad_km_h = 80
tiempo = recorrido_km / velocidad_km_h
assert type(tiempo) == float, "tiempo debería ser float"

# %% [markdown]
# ## **Tramos de un viaje**: dado un viaje dividido en tres tramos (120.0 km, 180.0 km y 95.0 km), evalúe y muestre con print() si al menos uno de los tramos superó los 150 km, combinando tres comparaciones con or.

# %%
tramo_a = 120.0
tramo_b = 180.0
tramo_c = 95.0
tramo_mayor_150 = tramo_a > 150 or tramo_b > 150 or tramo_c > 150
print("Sí hay un tramo mayor a 150" if tramo_mayor_150 else "No hay un tramo mayor a 150")
# Out:
# Sí hay un tramo mayor a 150
