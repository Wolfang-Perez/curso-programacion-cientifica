# %% [markdown]
# <a href="https://colab.research.google.com/github/Wolfang-Perez/curso-programacion-cientifica/blob/main/clase1_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicios

# %%
print("Hola mudo")
# Out:
# Hola mudo

# %%
from google.colab import userdata

# %%
userdata.get(githubToke)
